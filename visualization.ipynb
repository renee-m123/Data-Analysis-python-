# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,5))
x=[1,2,3,4,5]
y=[6,7,8,9,10]

plt.plot (x,y ,linewidth =5, color = 'green', label='Actual_Values')

x=[6,7,8,9,10]
y=[1,2,3,4,5]

plt.plot (x,y, linewidth =5, color = 'red', label='Predicted_Values')
#labelling the axis
plt.xlabel('x_axis', fontdict=fontdict)
plt.ylabel('y_axis', fontdict=fontdict)
plt.title("Dummy data bouble line graph" , loc= " Center", fontdict=fontdict )
plt.grid()
plt.legend(loc= 'upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 13
#      11 plt.plot (x,y, linewidth =5, color = 'red', label='Predicted_Values')
#      12 #labelling the axis
# ---> 13 plt.xlabel('x_axis', fontdict=fontdict)
#      14 plt.ylabel('y_axis', fontdict=fontdict)
#      15 plt.title("Dummy data bouble line graph" , loc= " Center", fontdict=fontdict )
#
# NameError: name 'fontdict' is not defined

# %%
x=[2,4,6,7,2]
daily_activities=['eating','study','sleep','work','leisure']

plt.pie(x, labels=daily_activities, autopct='%1.1f%%', explode=[0.1,0.1,0, 0, 0], colors=['b','r','g','y','purple'])

plt.show()

# %%
##SCATTER PLOT
x= [1,2,5,3,4]
y= [10,8,9,7,6,]

#plotting a scatter plot using a scatter function
plt.scatter(x,y, s=50, c='r', marker= '<', edgecolors= 'g')


#plotting a line graph to join the scatter dots
x=[1,2,5,3,4]
y= [10,8,9,7,6]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
###creating a scatter plot using random data
import numpy as np
import pandas as pd
df= pd.DataFrame(np.rand(10,3), columns= ['a','b','c'])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 df= pd.DataFrame(np.rand(10,3), columns= ['a','b','c'])
#       5 df
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\__init__.py:428, in __getattr__(attr)
#     425     import numpy.char as char
#     426     return char.chararray
# --> 428 raise AttributeError("module {!r} has no attribute "
#     429                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'rand'

# %%
ax=df1.plot.scatter(x='a',y='b', color='r', label="group 1")

df1.plot.scatter(x='c',y='d', color='g', label="group 2", ax=ax)

# %%
iris= pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\datasets\Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import seaborn as sns 
sns.scatterplot(x="SepalLengthCm", y="PetalLengthCm", data=iris, hue="Species")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
#generating random values
datas= np.random.rand(100)
plt.hist(datas, bins = 20)
plt.title("Histogram of randomly genrated data")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %%
datas
# Out:
# array([0.20940813, 0.10660793, 0.71775744, 0.53958012, 0.30620366,
#        0.0662639 , 0.9163527 , 0.05393609, 0.51397772, 0.26139356,
#        0.80608148, 0.85817346, 0.80349908, 0.51396334, 0.61467552,
#        0.30119136, 0.08158607, 0.47458862, 0.80053744, 0.02315519,
#        0.96497624, 0.87538948, 0.21220267, 0.69344395, 0.04809684,
#        0.80508511, 0.60673398, 0.56938045, 0.44217728, 0.02607501,
#        0.79664301, 0.33435763, 0.08485323, 0.03108534, 0.13242982,
#        0.03731609, 0.65701972, 0.95032717, 0.7169356 , 0.68532348,
#        0.31520542, 0.08164855, 0.92241199, 0.62860498, 0.8669619 ,
#        0.14436195, 0.20186876, 0.38934716, 0.0409211 , 0.5733106 ,
#        0.87169577, 0.66830706, 0.80178115, 0.10909174, 0.48762217,
#        0.94459754, 0.71551729, 0.53482654, 0.35749085, 0.69285096,
#        0.08868916, 0.68960644, 0.59911825, 0.74700316, 0.71600509,
#        0.35560258, 0.19415948, 0.21996003, 0.78963934, 0.31625282,
# ...

# %%
###bar graph using defined list of data
x= [2000,2007,2018]
y=[80,85,75]
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x= ['Peter','John','Sharon']
y=[80,85,75]
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>
